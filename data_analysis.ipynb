# %%
import pandas as pd
pd.set_option('display.max_columns', 55)

# %%
df = pd.read_csv('listings.csv')
dftax = pd.read_csv('dftax.csv')
df = df.drop(columns='Unnamed: 0')
dftax = dftax.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#    listing_id   state     user_id  category_id  \
# 0   761624516  active  51880063.0   68889208.0
# 1   595968061  active  64847802.0   68887494.0
# 2   497762742  active  11198800.0   69150433.0
# 3   618658978  active  54878959.0   68887482.0
# 4   780358369  active   5592903.0   68887336.0
#
#                                                title  \
# 0  Busy Book, Toddler Busy Book, Toddler Activiti...
# 1                   Vintage Sachet - Lavender Filled
# 2               Triple Grooved Trivet - 6&quot; long
# 3                   shoe clips dark blue velvet bows
# 4  9.25&quot; Heavy Absorbency Ultrathin Waterpro...
#
#                                          description  price currency_code  \
# 0  This Busy Book is a great way for your toddler...  38.00           USD
# 1  THIS set of repurposed vintage sachets are fil...  17.00           USD
# 2  Designed for group firing small pieces along t...  10.45           USD
# 3  Shoe clips dark blue velvet bows will add uniq...  10.00           USD
# 4  This pad is ready to ship.\n\nThis pad is read...   8.99           USD
#
#    quantity                                               tags  \
# 0       3.0  ['book', 'kindergarten', 'toys', 'games', 'pre...
# 1       1.0  ['Vintage Sachet', 'Lavender Sachet', 'Lavende...
# 2       2.0  ['trivet', 'kiln', 'kiln firing', 'firing triv...
# 3       1.0  ['shoe clips', ' shoe accessories', ' shoe dec...
# 4       1.0  ['cloth menstrual', 'mama', 'reusable', 'washa...
#
#           category_path     category_path_ids  \
# 0  ['Toys', 'Children']  [69150393, 68889208]
# 1          ['Weddings']            [68887494]
# 2          ['Supplies']            [69150433]
# 3           ['Jewelry']            [68887482]
# 4   ['Bath and Beauty']            [68887336]
#
#                                            materials  shop_section_id  \
# 0                                                 []       28009752.0
# 1      ['Vintage Linen', 'Satin Ribbon', 'Lavender']       23429088.0
# 2                                ['trivet', 'steel']       20026436.0
# 3                                                 []              NaN
# 4  ['Bamboo', 'Organic Cotton', 'Polyacetal Resin...        7137925.0
#
#                                                  url   views  num_favorers  \
# 0  https://www.etsy.com/listing/761624516/busy-bo...  1987.0         137.0
# 1  https://www.etsy.com/listing/595968061/vintage...    45.0           1.0
# 2  https://www.etsy.com/listing/497762742/triple-...   480.0          30.0
# 3  https://www.etsy.com/listing/618658978/shoe-cl...    74.0           4.0
# 4  https://www.etsy.com/listing/780358369/925-hea...     0.0           0.0
#
#    processing_min  processing_max  is_supply      when_made recipient  \
# 0            15.0            20.0      False      2020_2020       NaN
# 1             1.0             2.0      False      2010_2019       NaN
# 2             1.0             2.0       True      2020_2020       NaN
# 3             3.0             5.0      False  made_to_order       NaN
# 4             1.0             3.0      False      2020_2020       NaN
#
#   occasion language  taxonomy_id  \
# 0      NaN    en-US       2056.0
# 1      NaN    en-US       1666.0
# 2      NaN    en-US       6261.0
# 3      NaN    en-US       2147.0
# 4      NaN    en-US        274.0
#
#                                        taxonomy_path
# 0  ['Toys & Games', 'Toys', 'Baby & Toddler Toys'...
# 1  ['Weddings', 'Gifts & Mementos', "Bridesmaids'...
# 2  ['Craft Supplies & Tools', 'Frames, Hoops & St...
# 3  ['Jewelry', 'Brooches, Pins & Clips', 'Clothin...
# 4  ['Bath & Beauty', 'Personal Care', 'Menstrual ...

# %%
df.url
# Out:
# 0        https://www.etsy.com/listing/761624516/busy-bo...
# 1        https://www.etsy.com/listing/595968061/vintage...
# 2        https://www.etsy.com/listing/497762742/triple-...
# 3        https://www.etsy.com/listing/618658978/shoe-cl...
# 4        https://www.etsy.com/listing/780358369/925-hea...
#                                ...
# 50076    https://www.etsy.com/listing/676531047/vintage...
# 50077    https://www.etsy.com/listing/676517087/cheetah...
# 50078    https://www.etsy.com/listing/664377698/pink-an...
# 50079    https://www.etsy.com/listing/780452325/tirol-t...
# 50080    https://www.etsy.com/listing/766579904/hochzei...
# Name: url, Length: 50081, dtype: object
